# %% [markdown]
# # HELP - XMM-LSS Master List Creation
#
# This notebook presents the creation of the HELP master list on the XMM-LSS field. This field was already processed by Eduardo so this field may be validated against the old catalogue.
#
# <table>
#   <tr>
#     <th>Survey/Telescope/Instrument</th>
#     <th>Filters</th>
#     <th>Location</th>
#     <th>Notes</th>
#   </tr>
#   <tr>
#     <td>VIDEO/VISTA/VIRCAM</td>
#     <td>Z,Y,J,H,K</td>
#     <td>dmu0_VISTA-VIDEO, dmu0_VISTA-VIDEO-private</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>VIKING/VISTA/VIRCAM</td>
#     <td></td>
#     <td>dmu0_VISTA-VIKING</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>VHS/VISTA/VIRCAM</td>
#     <td></td>
#     <td>dmu0_VISTA-VHS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>UKIDSS DXS/UKIRT/WFCAM</td>
#     <td>J,K</td>
#     <td>dmu0_UKIDSS-DXS, dmu0_ELAIS-N1_DXS</td>
#     <td>???</td>
#   </tr>
#   <tr>
#     <td>SWIRE	Spitzer	IRAC234 & MIPS123		</td>
#     <td></td>
#     <td>dmu0_DataFusion-Spitzer</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SERVS	Spitzer	IRAC</td>
#     <td>???</td>
#     <td>dmu0_DataFusion-Spitzer</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>HSC SSC PDR1/Subaru/HSC</td>
#     <td>griYz + narrowband?</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>PS1 3PS/Pan-STARRS1		</td>
#     <td>grizy</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>PS1 MDS/Pan-STARRS1</td>
#     <td>grizy</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>CFHTLS Wide/CFHT/MegaCam		</td>
#     <td>u*, g', r', z' and either i' or y</td>
#     <td>dmu0_CFHTLS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>CFHTLS Deep/CFHT/MegaCam		</td>
#     <td>u*, g', r', z' and either i' or y</td>
#     <td>dmu0_CFHTLS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>UKIDSS UDS/UKIRT/WFCAM</td>
#     <td>J,H,K</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SXDS/Subaru/SuprimeCam</td>
#     <td>B,V,R,I,z</td>
#     <td>dmu0_SXDS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SpUDS	Spitzer	IRAC1234 & MIPS1</td>
#     <td></td>
#     <td>dmu0_SpUDS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SpARCS/CFHT/MegaCam</td>
#     <td></td>
#     <td>dmu0_SpARCS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>DES-DEEP/Blanco/DECAM	</td>
#     <td>grizy</td>
#     <td>???</td>
#     <td>???</td>
#   </tr>
#   <tr>
#     <td>CFHTLenS/CFHT/MegaCam</td>
#     <td>u,g,r,i,z</td>
#     <td>dmu0_CFHTLenS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>CANDELS/3D-HST</td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
# </table>

# %%
from herschelhelp_internal import git_version
print("This notebook was run with herschelhelp_internal version: \n{}".format(git_version()))
