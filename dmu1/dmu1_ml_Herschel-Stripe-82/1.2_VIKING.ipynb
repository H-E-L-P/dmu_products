# %% [markdown]
# # HELP - Herschel Stripe 82 Master List Creation
#
# This notebook presents the creation of the HELP master list on the Herschel Stripe 82 field.
#
#
# <table>
#   <tr>
#     <th>Survey/Telescope/Instrument</th>
#     <th>Filters</th>
#     <th>Location</th>
#     <th>Notes</th>
#   </tr>
#   <tr>
#     <td>SDSS Stripe 82/SDSS		</td>
#     <td>ugriz</td>
#     <td></td>
#     <td>Include catalogue or just use ids like for SDSS?</td>
#   </tr>
#   <tr>
#     <td>VIKING/VISTA/VIRCAM/</td>
#     <td>???</td>
#     <td>dmu0_VISTA-VIKING</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>VHS/VISTA/VIRCAM</td>
#     <td>???</td>
#     <td>dmu0_VISTA-VHS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>VICS82/VISTA-CFHT/VIRCAM-WIRCAM</td>
#     <td>J,K</td>
#     <td>dmu0_VICS82</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>UKIDSS-DXS/UKIRT/WFCAM</td>
#     <td>J,K</td>
#     <td>dmu0_UKIDSS-DXS, dmu0_ELAIS-N1_DXS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>UKIDSS LAS/UKIRT/WFCAM</td>
#     <td>Y,J,H,K</td>
#     <td>dmu0_UKIDSS-LAS</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SHELA/Spitzer/IRAC</td>
#     <td>IRAC12</td>
#     <td>dmu0_SHELA</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SpIES/Spitzer/IRAC</td>
#     <td>IRAC12</td>
#     <td>dmu0_SpIES</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>HSC SSC PDR1/Subaru/HSC</td>
#     <td></td>
#     <td></td>
#     <td>Where/when?</td>
#   </tr>
#   <tr>
#     <td>PS1 3PS/Pan-STARRS1</td>
#     <td>grizy</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>CS82/CFHT/MegaCam/</td>
#     <td>i</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>DES-WIDE/Blanco/DECAM</td>
#     <td>grizy</td>
#     <td></td>
#     <td></td>
#   </tr>
# </table>

# %%
from herschelhelp_internal import git_version
print("This notebook was run with herschelhelp_internal version: \n{}".format(git_version()))
