# %% [markdown]
# # Validation report for dmu26_XID+MIPS_COSMOS_20170213

# %% [markdown]
# The data product dmu26_XID+MIPS_COSMOS_20170213, contains two files:
#
# 1. dmu26_XID+MIPS_COSMOS_20170213.fits: The catalogue file
# 2. dmu26_XID+MIPS_COSMOS_20170213_Bayes_pval.fits: The Bayesian pvalue map

# %% [markdown]
# ## Catalogue Validation
# Validation of the catalogue should cover the following as a minimum:
#
# * Compare XID+ Fluxes with previous catalogues
# * Check for sources with poor convergence (i.e. $\hat{R}$ >1.2 and $n_{eff}$ <40)
# * Check for sources with strange error (i.e. small upper limit and large lower limit, which would be indicating prior is limiting flux)
# * Check for sources that return prior (i.e. probably very large flux and large error)
# * Check background estimate is similar across neighbouring tiles (will vary depending on depth of prior list)

# %%
from astropy.table import Table
import numpy as np
import pylab as plt
# %matplotlib inline

# %%
table=Table.read('/Users/williamp/validation/cosmos/MIPS24/dmu26_XID+MIPS_COSMOS_20170213.fits', format='fits')
# Out:
# WARNING: UnitsWarning: 'degrees' did not parse as fits unit: At col 0, Unit 'degrees' not supported by the FITS standard.  [astropy.units.core]
# WARNING:astropy:UnitsWarning: 'degrees' did not parse as fits unit: At col 0, Unit 'degrees' not supported by the FITS standard.

# %%
#table[:10].show_in_notebook()
# Out:
# &lt;Table length=10&gt;
# <table id="table4432078224-649204" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>help_id</th><th>RA</th><th>Dec</th><th>F_MIPS_24</th><th>FErr_MIPS_24_u</th><th>FErr_MIPS_24_l</th><th>Bkg_MIPS_24</th><th>Sig_conf_MIPS_24</th><th>Rhat_MIPS_24</th><th>n_eff_MIPS_24</th><th>Pval_res_24</th></tr></thead>
# <thead><tr><th></th><th></th><th>degrees</th><th>degrees</th><th>uJy</th><th>uJy</th><th>uJy</th><th>MJy / sr</th><th>MJy / sr</th><th></th><th></th><th></th></tr></thead>
# <tr><td>0</td><td>HELP_J100019.68+012956.21</td><td>150.081982461</td><td>1.49894688148</td><td>1.7369</td><td>4.06482</td><td>0.459711</td><td>-0.00730268</td><td>5.16168e-06</td><td>0.999888</td><td>2000.0</td><td>0.0</td></tr>
# <tr><td>1</td><td>HELP_J100022.32+012956.58</td><td>150.093019719</td><td>1.49904896278</td><td>0.534336</td><td>1.40479</td><td>0.138139</td><td>-0.00730268</td><td>5.16168e-06</td><td>1.00081</td><td>2000.0</td><td>0.0</td></tr>
# <tr><td>2</td><td>HELP_J100020.61+012956.18</td><td>150.085859377</td><td>1.49893773756</td><td>0.420404</td><td>1.0317</td><td>0.114966</td><td>-0.00730268</td><td>5.16168e-06</td><td>0.999397</td><td>2000.0</td><td>0.0</td></tr>
# <tr><td>3</td><td>HELP_J100019.96+012958.61</td><td>150.083147288</td><td>1.49961385853</td><td>0.815015</td><td>2.11498</td><td>0.226545</td><td>-0.00730268</td><td>5.16168e-06</td><td>0.998404</td><td>2000.0</td><td>0.0</td></tr>
# <tr><td>4</td><td>HELP_J100024.06+012959.33</td><td>150.100251231</td><td>1.4998144436</td><td>1.5809</td><td>3.97616</td><td>0.415317</td><td>-0.00730268</td><td>5.16168e-06</td><td>0.998802</td><td>2000.0</td><td>1.0</td></tr>
# <tr><td>5</td><td>HELP_J100023.65+013001.20</td><td>150.098528505</td><td>1.50033288163</td><td>0.859798</td><td>2.17176</td><td>0.251819</td><td>-0.00730268</td><td>5.16168e-06</td><td>0.998575</td><td>2000.0</td><td>0.0</td></tr>
# <tr><td>6</td><td>HELP_J100021.22+012958.28</td><td>150.088411566</td><td>1.4995229716</td><td>1.89148</td><td>4.15636</td><td>0.521933</td><td>-0.00730268</td><td>5.16168e-06</td><td>0.998669</td><td>2000.0</td><td>0.0</td></tr>
# <tr><td>7</td><td>HELP_J100022.87+013002.79</td><td>150.09530976</td><td>1.50077368948</td><td>0.604834</td><td>1.53436</td><td>0.149797</td><td>-0.00730268</td><td>5.16168e-06</td><td>0.998428</td><td>2000.0</td><td>0.0</td></tr>
# <tr><td>8</td><td>HELP_J100024.58+013004.76</td><td>150.102425265</td><td>1.50132199264</td><td>7.59358</td><td>12.5476</td><td>3.13757</td><td>-0.00730268</td><td>5.16168e-06</td><td>1.00185</td><td>1283.0</td><td>1.0</td></tr>
# <tr><td>9</td><td>HELP_J100020.72+013005.04</td><td>150.086323824</td><td>1.50140062119</td><td>5.14413</td><td>10.1896</td><td>1.70297</td><td>-0.00730268</td><td>5.16168e-06</td><td>1.00089</td><td>2000.0</td><td>0.0</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.9/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table4432078224-649204').dataTable()");
#     $('#table4432078224-649204').dataTable({
#         "order": [],
#         "iDisplayLength": 50,
#         "aLengthMenu": [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         "pagingType": "full_numbers"
#     });
# });
# </script>

# %%
import seaborn as sns
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# ### Comparison to previous catalogues
# Suggest using COSMOS2015 catalogue and preexisiting Le'Floch 2009 fluxes as comparison. (can get table from HeDAM VO server)

# %%
table.sort('help_id')

COSMOS2015 = Table.read('/Users/williamp/validation/cosmos/MIPS24/COSMOS2015_Laigle+_v1.1_wHELPids_IRAC.fits')
COSMOS2015.sort('help_id')

# %%
plt.scatter(np.log10(table['F_MIPS_24']), np.log10(COSMOS2015['FLUX_24']))
plt.xlabel('$\log_{10}S_{24 \mathrm{\mu m}, XID+}$')
plt.ylabel('$\log_{10}S_{24 \mathrm{\mu m}, COSMOS2015}$')
plt.show()

plot=sns.jointplot(x=np.log10(table['F_MIPS_24']), y=np.log10(COSMOS2015['FLUX_24']), xlim=(-1,6), kind='hex')
plot.set_axis_labels('$\log_{10}S_{24 \mathrm{\mu m}, XID+}$', '$\log_{10}S_{24 \mathrm{\mu m}, COSMOS2015}$')
plt.show()

# %% [markdown]
# The agreement is reasonably good. As would be expected, the lower flux density objects are typically given a lower flux density by XID+ than in the catalogue due to the higher source density resulting in greater deblending effects. At the bright end, the two catalogues converge, again as would be expected. There are 972 with curiously high flux densities; these objects are explored more below.
#
# Note that the XID+ results have a set of 972 objects with fluxes of > 1e5  $\mu$Jy.
# These objects have good n$_{eff}$ and $\hat{R}$ values.
# They are also not overly skewed (see plots below).

# %% [markdown]
# ### Convergence Statistics
# e.g. How many of the objects satisfy critera?
# (note Some of the $\hat{R}$ values are NaN. This is a PyStan bug. They are most likely 1.0

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
Rhat=plt.hist(np.isfinite(table['Rhat_MIPS_24']), bins=np.arange(0.9,1.2,0.01))
plt.xlabel(r'$\hat{R}$')
plt.subplot(1,2,2)
neff=plt.hist(table['n_eff_MIPS_24'])
plt.yscale('log')
plt.xlabel(r'$n_{eff.}$')

# %%
numRhat = 0
numNeff = 0

for i in range(0, len(table)):
    if table['Rhat_MIPS_24'][i] > 1.2 and np.isfinite(table['Rhat_MIPS_24']):
        numRhat += 1
    if table['n_eff_MIPS_24'][i] < 40:
        numNeff += 1
        
print(str(numRhat)+' objects have $\hat{R}$ > 1.2')
print(str(numNeff)+' objects have n$_{eff}$ < 40')
# Out:
# 0 objects have $\hat{R}$ > 1.2
# 0 objects have n$_{eff}$ < 40

# %% [markdown]
# All objects have good $\hat{R}$ and n$_{eff}$ values

# %% [markdown]
# ### Skewness

# %%
FLUX_24 = np.log10(table['F_MIPS_24'])
ERR_ratio = (table['FErr_MIPS_24_u']-table['F_MIPS_24'])/(table['F_MIPS_24']-table['FErr_MIPS_24_l'])
plot=sns.jointplot(x=FLUX_24, y=ERR_ratio, xlim=(-1,6), kind='hex')
plot.set_axis_labels(r'$\log_{10}S_{24 \mathrm{\mu m}}$ ', r'$(84^{th}-50^{th})/(50^{th}-16^{th})$ percentiles')

# %% [markdown]
# ### Sources where posterior=prior
# Suggest looking at size of errors to diagnose. How many appear to be returning prior? Where are they on Bayesian P value map? Does it make sense why?

# %% [markdown]
# None appear to have large lower errors and small upper errors. Objects below ~5 $\mu$Jy are perhaps limited at the lower flux end. This makes sense as these objects are faint are also likely to be uncertain but the lower flux limit cuts the size of the lower error - Will

# %% [markdown]
# #Looking at the high flux objects
# Looking at the errors on the high flux objects to see if they are prior limited.

# %%
bRA = []
bDec = []
bF_MIPS_24 = []
bFErr_MIPS_24_u = []
bFErr_MIPS_24_l = []
for i in range(0, len(table)):
    if table['F_MIPS_24'][i] > 1e5:
        bRA.append(table['RA'][i])
        bDec.append(table['Dec'][i])
        bF_MIPS_24.append(table['F_MIPS_24'][i])
        bFErr_MIPS_24_u.append(table['FErr_MIPS_24_u'][i])
        bFErr_MIPS_24_l.append(table['FErr_MIPS_24_l'][i])
        
bFErr_MIPS_24 = []
for i in range(0, len(bF_MIPS_24)):
    if bF_MIPS_24[i] - bFErr_MIPS_24_l[i] > bFErr_MIPS_24_u[i] - bF_MIPS_24[i]:
        bFErr_MIPS_24.append(bF_MIPS_24[i] - bFErr_MIPS_24_l[i])
    else:
        bFErr_MIPS_24.append(bFErr_MIPS_24_u[i] - bF_MIPS_24[i])

# %%
plt.scatter(np.log10(bF_MIPS_24), np.log10(bFErr_MIPS_24_u))
plt.xlabel('$\log_{10}S_{24 \mathrm{\mu m}}$')
plt.ylabel('$\log_{10}\sigma_{24 \mathrm{\mu m}, upper}$')
plt.show()

plt.scatter(np.log10(bF_MIPS_24), np.log10(bFErr_MIPS_24_l))
plt.xlabel('$\log_{10}S_{24 \mathrm{\mu m}}$')
plt.ylabel('$\log_{10}\sigma_{24 \mathrm{\mu m}, lower}$')
plt.show()

plt.scatter(np.log10(bF_MIPS_24), np.log10(bFErr_MIPS_24))
plt.xlabel('$\log_{10}S_{24 \mathrm{\mu m}}$')
plt.ylabel('$\log_{10}\sigma_{24 \mathrm{\mu m}}$')
plt.plot([5.85,5.93],[5.66,5.80])
plt.xlim(5.85,5.93)
plt.ylim(5.66,5.80)
plt.show()

# %% [markdown]
# The flux errors seem to be large (approaching 100%) so the data for these objects seems poorly constrained but not prior limited. It is a supprise that these flux densities are so high although with such large errors, they may not actually be this large. Their positions on the map suggest they are a leftover from the masking. The P-values being ~0 suggests that this is the case.
#
# Line in the last plot is the 1-to-1 line

# %% [markdown]
# ### Background value
# Are all the background values similar? For those that aren't is it obvious why? (e.g. edge of map, extended source not fitted well etc)

# %%
plt.hist(table['Bkg_MIPS_24'])
plt.xlabel(r'Background (MJy/sr)')
plt.show()

# %% [markdown]
# The background values seem pretty consistent around -0.015.

# %% [markdown]
# -------------
# ## Bayesian P value map
# The Bayesian P value map can be thought of as a more robust residual map. They provide the probability our model would obtain the pixel data value, having inferred our model on the data. The probabilitiy value is expressed in terms of a sigma value.
#
# * a value of < -2 indicates that our model cannot explain why there is so little flux in the map
# * a value of > -2 indicates our model cannot explain why there is so much flux in the map
# * a value of ~ 0 indicates a good fit
#
# Plotting the distribution of the Bayesian P value map can indicate whether the map has been been fit well in general. If the distribution is centered on 0 and roughly symmetric then it is a good fit.
#
# Suggested validation checks:
#
# * Check distribution is reasonable
# * Check for strange areas in map

# %%
import aplpy
from astropy.io import fits

# %%
hdulist=fits.open('/Users/williamp/validation/cosmos/MIPS24/dmu26_XID+MIPS_COSMOS_20170213_Bayes_pval.fits')

# %%
plt.figure()
Bayes_hist=plt.hist(np.isfinite(hdulist[1].data), bins=np.arange(-6,6.1,0.05))
plt.xlabel(r'$\sigma$ value')
plt.show()

# %% [markdown]
# P-values seem to cluster around 0 and 1, which many more objects at 0 than 1 (the histogram doesn't show this well). The position of objects with P-value > 0.5 are plotted below.

# %% [markdown]
# #Checking the positions
# Using the MIPS map to check where the high flux objects and objects with highish bakground are.

# %%
#from astropy import wcs

# %%
hdulist = fits.open('/Users/williamp/dev/XID_plus/input/cosmosKs/mips_24_GO3_sci_10.fits')
#Note, this mips map was the newest map I could find from S_COSMOS. I'm pretty sure is is not what was used in the XID+ run - Will
hdulist[0].header['CTYPE1'] = 'RA'
hdulist[0].header['CTYPE2'] = 'DEC'

# %% [markdown]
# MIPS 24 map is in greyscale, object positions are in blue, objects with fluxes > 1e5 are in red, objects with background values > 0 MJy/sr are in yellow, objects with P-values > 0.5 are in green.

# %%
#vmin=0.0001
#vmax=0.02
fig = plt.figure(figsize=(30,10))
pltut = aplpy.FITSFigure(hdulist, figure=fig)

pltut.show_colorscale(vmin=vmin,vmax=vmax,cmap='Greys',stretch='log')

pltut.show_circles(table['RA'],table['Dec'], radius=0.0025, color='b')

bRA = []
bDec = []
for i in range(0, len(table)):
    if table['F_MIPS_24'][i] > 1e5:
        bRA.append(table['RA'][i])
        bDec.append(table['Dec'][i])
pltut.show_circles(bRA, bDec, radius=0.005, color='r')

bgRA = []
bgDec = []
for i in range(0, len(table)):
    if table['Bkg_MIPS_24'][i] > 0:
        bgRA.append(table['RA'][i])
        bgDec.append(table['Dec'][i])
pltut.show_circles(bgRA, bgDec, radius=0.005, color='y')

pRA = []
pDec = []
for i in range(0, len(table)):
    if table['Pval_res_24'][i] > 0.5:
        pRA.append(table['RA'][i])
        pDec.append(table['Dec'][i])
pltut.show_circles(pRA, pDec, radius=0.005, color='g')

plt.show()

# %% [markdown]
# The high flux value objects (red) appear to cluster arround the edges of the masked regions, so may just be artefacts of bad masking.
#
# The high background objects (yellow) appear to be a property of individual tiles as they form squares on the image above. These tiles are either on the edge of the map or in the bottom left, by the large masked areas. A visual inspection of the map in these tiles does not show anything unique about these areas.
#
# The high P-value objects (green) appear arround brighter objects (but not all bright objects) which makes sense; bright blended objects are harder to deblend than non-blended objects. They also often coincide with the high background tiles.
