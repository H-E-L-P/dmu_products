# %% [markdown]
# # Validation report for dmu26_XID+PACS_COSMOS_20170303

# %% [markdown]
# The data product dmu26_XID+PACS_COSMOS_20170303, contains three files:
#
# 1. dmu26_XID+PACS_COSMOS_20170303.fits: The catalogue file
# 2. dmu26_XID+PACS_COSMOS_20170303_Bayes_pval_PACS100.fits: The Bayesian pvalue map
# 3. dmu26_XID+PACS_COSMOS_20170303_Bayes_pval_PACS160.fits: The Bayesian pvalue map

# %% [markdown]
# ## Catalogue Validation
# Validation of the catalogue should cover the following as a minimum:
#
# * Compare XID+ Fluxes with previous catalogues
# * Check for sources with poor convergence (i.e. $\hat{R}$ >1.2 and $n_{eff}$ <40)
# * Check for sources with strange error (i.e. small upper limit and large lower limit, which would be indicating prior is limiting flux)
# * Check for sources that return prior (i.e. probably very large flux and large error)
# * Check background estimate is similar across neighbouring tiles (will vary depending on depth of prior list)

# %%
from astropy.table import Table
import numpy as np
import pylab as plt
# %matplotlib inline

# %%
table=Table.read('/Users/williamp/validation/cosmos/PACS/dmu26_XID+PACS_COSMOS_20170303.fits', format='fits')
# Out:
# WARNING: UnitsWarning: 'degrees' did not parse as fits unit: At col 0, Unit 'degrees' not supported by the FITS standard.  [astropy.units.core]
# WARNING:astropy:UnitsWarning: 'degrees' did not parse as fits unit: At col 0, Unit 'degrees' not supported by the FITS standard.

# %%
table[:10].show_in_notebook()
# Out:
# &lt;Table length=10&gt;
# <table id="table4440568592-347133" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>HELP_ID</th><th>RA</th><th>Dec</th><th>F_PACS_100</th><th>FErr_PACS_100_u</th><th>FErr_PACS_100_l</th><th>F_PACS_160</th><th>FErr_PACS_160_u</th><th>FErr_PACS_160_l*1000.0</th><th>Bkg_PACS_100</th><th>Bkg_PACS_160</th><th>Sig_conf_PACS_100</th><th>Sig_conf_PACS_160</th><th>Rhat_PACS_100</th><th>Rhat_PACS_160</th><th>n_eff_PACS_100</th><th>n_eff_PACS_160</th><th>Pval_res_100</th><th>Pval_res_160</th></tr></thead>
# <thead><tr><th></th><th></th><th>degrees</th><th>degrees</th><th>mJy</th><th>mJy</th><th>mJy</th><th>mJy</th><th>mJy</th><th>mJy</th><th>MJy / sr</th><th>MJy / sr</th><th>MJy / sr</th><th>MJy / sr</th><th></th><th></th><th></th><th></th><th></th><th></th></tr></thead>
# <tr><td>0</td><td>HELP_J100019.68+012956.21</td><td>150.081982461</td><td>1.49894688148</td><td>0.165499659488</td><td>0.454144115793</td><td>0.0402466685046</td><td>6.04484556243</td><td>9.01419576257</td><td>0.00328089</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>0.998417</td><td>1.0019</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0</td></tr>
# <tr><td>1</td><td>HELP_J100022.32+012956.58</td><td>150.093019719</td><td>1.49904896278</td><td>0.378230499336</td><td>0.908303016331</td><td>0.0857893974171</td><td>0.41579187382</td><td>1.11066433601</td><td>0.000107954</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>0.998904</td><td>0.999649</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0015</td></tr>
# <tr><td>2</td><td>HELP_J100020.61+012956.18</td><td>150.085859377</td><td>1.49893773756</td><td>0.194308071514</td><td>0.525390496477</td><td>0.0445684127044</td><td>3.94020695239</td><td>6.73015136272</td><td>0.00172247</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>0.99847</td><td>1.00002</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0</td></tr>
# <tr><td>3</td><td>HELP_J100019.96+012958.61</td><td>150.083147288</td><td>1.49961385853</td><td>0.208110097446</td><td>0.554249505512</td><td>0.0521120527992</td><td>1.01182132494</td><td>2.46661296114</td><td>0.000228307</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>0.999653</td><td>1.00025</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0</td></tr>
# <tr><td>4</td><td>HELP_J100024.06+012959.33</td><td>150.100251231</td><td>1.4998144436</td><td>0.322804786265</td><td>0.817092717625</td><td>0.0807043543318</td><td>0.589141622186</td><td>1.46596308332</td><td>0.000146005</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>0.998957</td><td>1.00078</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0355</td></tr>
# <tr><td>5</td><td>HELP_J100023.65+013001.20</td><td>150.098528505</td><td>1.50033288163</td><td>0.605823006481</td><td>1.36854615994</td><td>0.168487851624</td><td>0.240177789237</td><td>0.641155638732</td><td>5.72788e-05</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>1.00017</td><td>0.999077</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.023</td></tr>
# <tr><td>6</td><td>HELP_J100021.22+012958.28</td><td>150.088411566</td><td>1.4995229716</td><td>0.125120335724</td><td>0.32799350447</td><td>0.0313700220431</td><td>1.05594145134</td><td>2.47328146361</td><td>0.000293881</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>0.999561</td><td>0.99938</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0</td></tr>
# <tr><td>7</td><td>HELP_J100022.87+013002.79</td><td>150.09530976</td><td>1.50077368948</td><td>1.89557706472</td><td>2.88701569661</td><td>0.919760728721</td><td>0.23427020642</td><td>0.638925877865</td><td>5.44659e-05</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>1.00097</td><td>0.998518</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.041</td></tr>
# <tr><td>8</td><td>HELP_J100024.58+013004.76</td><td>150.102425265</td><td>1.50132199264</td><td>0.991385662928</td><td>1.98723771609</td><td>0.31036263681</td><td>1.03455292992</td><td>2.57391063496</td><td>0.000285297</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>1.00052</td><td>0.999491</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0</td></tr>
# <tr><td>9</td><td>HELP_J100020.72+013005.04</td><td>150.086323824</td><td>1.50140062119</td><td>0.24874281371</td><td>0.61558483867</td><td>0.0643294188194</td><td>0.404384743888</td><td>1.10872671939</td><td>9.81698e-05</td><td>0.954947</td><td>0.922036</td><td>0.496438</td><td>0.134244</td><td>0.999614</td><td>0.998579</td><td>2000.0</td><td>2000.0</td><td>1.0</td><td>0.0</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.9/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table4440568592-347133').dataTable()");
#     $('#table4440568592-347133').dataTable({
#         "order": [],
#         "iDisplayLength": 50,
#         "aLengthMenu": [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         "pagingType": "full_numbers"
#     });
# });
# </script>

# %%
import seaborn as sns
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# ### Comparison to previous catalogues
# Using COSMOS2015 catalogue and matching to closest PACS objects within 1''

# %%
#table.sort('help_id')

COSMOS2015 = Table.read('/Users/williamp/validation/cosmos/PACS/COSMOS2015_Laigle+v1.1_wHELPids_PACS_green.fits')
COSMOS2015.sort('HELP_ID')

# %%
plt.scatter(np.log10(COSMOS2015['F_PACS_100']), np.log10(COSMOS2015['FLUX_100']))
plt.xlabel('$\log_{10}S_{100 \mathrm{\mu m}, XID+}$')
plt.ylabel('$\log_{10}S_{100 \mathrm{\mu m}, COSMOS2015}$')
plt.show()

plot=sns.jointplot(x=np.log10(COSMOS2015['F_PACS_100']), y=np.log10(COSMOS2015['FLUX_100']), xlim=(-1,3), kind='hex')
plot.set_axis_labels('$\log_{10}S_{100 \mathrm{\mu m}, XID+}$', '$\log_{10}S_{100 \mathrm{\mu m}, COSMOS2015}$')
plt.show()

# %% [markdown]
# Agreement is reasonable good. Lower flux objects can be given lower flux density by XID+ as would be expecetd. High flux density objects have a convergance in XID+ and COSMOS2015 as would be expected.

# %% [markdown]
# ### Convergence Statistics
# e.g. How many of the objects satisfy critera?
# (note Some of the $\hat{R}$ values are NaN. This is a PyStan bug. They are most likely 1.0

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
Rhat=plt.hist(np.isfinite(table['Rhat_PACS_100']), bins=np.arange(0.9,1.2,0.01))
plt.xlabel(r'$\hat{R}$')
plt.subplot(1,2,2)
neff=plt.hist(table['n_eff_PACS_100'])
plt.yscale('log')
plt.xlabel(r'$n_{eff.}$')

# %%
numRhat = 0
numNeff = 0

for i in range(0, len(table)):
    if table['Rhat_PACS_100'][i] > 1.2 and np.isfinite(table['Rhat_PACS_100']):
        numRhat += 1
    if table['n_eff_PACS_100'][i] < 40:
        numNeff += 1
        
print(str(numRhat)+' objects have $\hat{R}$ > 1.2')
print(str(numNeff)+' objects have n$_{eff}$ < 40')
# Out:
# 0 objects have $\hat{R}$ > 1.2
# 0 objects have n$_{eff}$ < 40

# %% [markdown]
# All objects have good $\hat{R}$ and n$_{eff}$ values

# %% [markdown]
# ### Skewness

# %%
plot=sns.jointplot(x=np.log10(table['F_PACS_100']), y=(table['FErr_PACS_100_u']-table['F_PACS_100'])/(table['F_PACS_100']-table['FErr_PACS_100_l']), xlim=(-1,2), kind='hex')
plot.set_axis_labels(r'$\log_{10}S_{24 \mathrm{\mu m}}$ ', r'$(84^{th}-50^{th})/(50^{th}-16^{th})$ percentiles')

# %% [markdown]
# ### Sources where posterior=prior
# Suggest looking at size of errors to diagnose. How many appear to be returning prior? Where are they on Bayesian P value map? Does it make sense why?

# %% [markdown]
# Objects below ~3$\mu$Jy are probably prior limited. The upper error becomes larger than the lower error suggesting the lower limit is limiting the size of the lower error.

# %% [markdown]
# ### Background value
# Are all the background values similar? For those that aren't is it obvious why? (e.g. edge of map, extended source not fitted well etc)

# %%
plt.hist(table['Bkg_PACS_100'])
plt.xlabel(r'Background (MJy/sr)')
plt.show()

# %% [markdown]
# The background seems to be reasomably large but roughly consistent around ~1.0

# %% [markdown]
# -------------
# ## Bayesian P value map
# The Bayesian P value map can be thought of as a more robust residual map. They provide the probability our model would obtain the pixel data value, having inferred our model on the data. The probabilitiy value is expressed in terms of a sigma value.
#
# * a value of < -2 indicates that our model cannot explain why there is so little flux in the map
# * a value of > -2 indicates our model cannot explain why there is so much flux in the map
# * a value of ~ 0 indicates a good fit
#
# Plotting the distribution of the Bayesian P value map can indicate whether the map has been been fit well in general. If the distribution is centered on 0 and roughly symmetric then it is a good fit.
#
# Suggested validation checks:
#
# * Check distribution is reasonable
# * Check for strange areas in map

# %%
import aplpy
from astropy.io import fits

# %%
hdulistP=fits.open('/Users/williamp/validation/cosmos/PACS/dmu26_XID+PACS_COSMOS_20170303_Bayes_pval_PACS100.fits')

# %%
plt.figure()
Bayes_hist=plt.hist(np.isfinite(hdulistP[1].data), bins=np.arange(-6,6.1,0.05))
plt.xlabel(r'$\sigma$ value')

# %% [markdown]
# #Checking the Positions
# Using the PACS map to check where the high flux objects and objects with highish bakground are.

# %%
hdulist = fits.open('/Users/williamp/dev/XID_plus/input/cosmosKs/pep_COSMOS_green_Map.DR1.fits')

hdulist[1].header['CTYPE1'] = 'RA'
hdulist[1].header['CTYPE2'] = 'DEC'

# %% [markdown]
# PACS_green map is in greyscale, object positions are in blue, objects with fluxes > 1e3 are in red, objects with background values > 2.5 MJy/sr are in yellow, objects with P-values > 0.5 are in green.

# %%
vmin=0.0001
vmax=0.02
fig = plt.figure(figsize=(30,10))
pltut = aplpy.FITSFigure(hdulist[1], figure=fig)

pltut.show_colorscale(vmin=vmin,vmax=vmax,cmap='Greys',stretch='log')

pltut.show_circles(table['RA'],table['Dec'], radius=0.0025, color='b')

pRA = []
pDec = []
for i in range(0, len(table)):
    if table['Pval_res_100'][i] > 0.5:
        pRA.append(table['RA'][i])
        pDec.append(table['Dec'][i])
print len(pRA)
if len(pRA) > 0:
    pltut.show_circles(pRA, pDec, radius=0.005, color='g')
    
bgRA = []
bgDec = []
for i in range(0, len(table)):
    if table['Bkg_PACS_100'][i] > 2.5:
        bgRA.append(table['RA'][i])
        bgDec.append(table['Dec'][i])
print len(bgRA)
if len(bgRA) > 0:
    pltut.show_circles(bgRA, bgDec, radius=0.005, color='y')
    
bRA = []
bDec = []
for i in range(0, len(table)):
    if table['F_PACS_100'][i] > 1e3:
        bRA.append(table['RA'][i])
        bDec.append(table['Dec'][i])
if len(bRA) > 0:
    pltut.show_circles(bRA, bDec, radius=0.005, color='r')

plt.show()
# Out:
# 319296
# 1402

# %% [markdown]
# The high flux value objects (red) appear to mainly cluster arround the edges of the masked regions, so may just be artefacts of bad masking.
#
# The high background objects (yellow) appear to be a property of individual tiles as they form squares on the image above. These tiles are on the edge of the map so possibly a result of this.
#
# Nearly all objects have high P-values (green). I do not know why this is. The entire map may need re-running.
